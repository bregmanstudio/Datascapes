# %% [markdown]
# <h1>MUS103 / MUS14.02: Datascapes</h1>
# <h2>Dartmouth College (Prof. Casey and Prof. Casas)</h2>
#
# <h1>Visualizing and Sonifying Helioseismology Data</h1>

# %% [markdown]
# <h1>Acquire</h1>

# %% [markdown]
# <h1>Parse</h1>
# <h3>Using python</h3>

# %%
from pylab import *
import os, sys
import glob
import Image
# %matplotlib inline
rcParams['figure.figsize'] = (10.0, 8.0)

# %%
flist = glob.glob("gong.nso.edu/data/magmap/QR/bq2/201501/*/*.jpg")
flist.sort() # in-place sorting of a list
print "number of images=",len(flist)
# Out:
# number of images= 742

# %%
flist[:10] # show the first 10 entries

# %%
flist[-10:] # show the last 10 entries
# Out:
# ['gong.nso.edu/data/magmap/QR/bq2/201501/mrbq2150131/mrbq2150131t1414c2160_309.jpg',
#  'gong.nso.edu/data/magmap/QR/bq2/201501/mrbq2150131/mrbq2150131t1504c2160_309.jpg',
#  'gong.nso.edu/data/magmap/QR/bq2/201501/mrbq2150131/mrbq2150131t1604c2160_308.jpg',
#  'gong.nso.edu/data/magmap/QR/bq2/201501/mrbq2150131/mrbq2150131t1714c2160_307.jpg',
#  'gong.nso.edu/data/magmap/QR/bq2/201501/mrbq2150131/mrbq2150131t1804c2160_307.jpg',
#  'gong.nso.edu/data/magmap/QR/bq2/201501/mrbq2150131/mrbq2150131t1914c2160_306.jpg',
#  'gong.nso.edu/data/magmap/QR/bq2/201501/mrbq2150131/mrbq2150131t2014c2160_306.jpg',
#  'gong.nso.edu/data/magmap/QR/bq2/201501/mrbq2150131/mrbq2150131t2104c2160_305.jpg',
#  'gong.nso.edu/data/magmap/QR/bq2/201501/mrbq2150131/mrbq2150131t2204c2160_305.jpg',
#  'gong.nso.edu/data/magmap/QR/bq2/201501/mrbq2150131/mrbq2150131t2304c2160_304.jpg']

# %%
jpgfile = Image.open(flist[0])
jpgfile.size
# Out:
# (420, 240)

# %%
imshow(jpgfile)

# %%
data = jpgfile.getdata()
imshow(grayim, cmap=cm.gray)

# %% [markdown]
# <h1>Working with High Resolution (uncompressed) FITS images</h1>

# %%
# in a terminal, type the command "sudo easy_install pyfits" to install the pyfits library
import pyfits   # a python library to read fits images

# %%
# 36-day time-series data from http://gong2.nso.edu/archive
f = pyfits.open('mrvmt150702d000.fits')
f.info()
# Out:
# Filename: mrvmt150702d000.fits
# No.    Name         Type      Cards   Dimensions   Format
# 0    PRIMARY     PrimaryHDU     215   (51840, 2, 2)   float32

# %%
plot(f[0].data[0,0,:])

# %%
from bregman.suite import *

# %%
play(f[0].data[0,0,:], 11025)
# Out:
# Period size is 64 , Buffer size is 5513

# %%
flist = glob.glob('gong.nso.edu/*/*/*/*/*/*/*.gz')
flist.sort()
print "num files=", len(flist)
# Out:
# num files= 103

# %%
flist[:10]
# Out:
# ['gong.nso.edu/data/magmap/QR/bqs/201601/mrbqs160101/mrbqs160101t0014c2172_214.fits.gz',
#  'gong.nso.edu/data/magmap/QR/bqs/201601/mrbqs160101/mrbqs160101t0104c2172_214.fits.gz',
#  'gong.nso.edu/data/magmap/QR/bqs/201601/mrbqs160101/mrbqs160101t0214c2172_213.fits.gz',
#  'gong.nso.edu/data/magmap/QR/bqs/201601/mrbqs160101/mrbqs160101t0304c2172_213.fits.gz',
#  'gong.nso.edu/data/magmap/QR/bqs/201601/mrbqs160101/mrbqs160101t0414c2172_212.fits.gz',
#  'gong.nso.edu/data/magmap/QR/bqs/201601/mrbqs160101/mrbqs160101t0504c2172_212.fits.gz',
#  'gong.nso.edu/data/magmap/QR/bqs/201601/mrbqs160101/mrbqs160101t0614c2172_211.fits.gz',
#  'gong.nso.edu/data/magmap/QR/bqs/201601/mrbqs160101/mrbqs160101t0704c2172_210.fits.gz',
#  'gong.nso.edu/data/magmap/QR/bqs/201601/mrbqs160101/mrbqs160101t0814c2172_210.fits.gz',
#  'gong.nso.edu/data/magmap/QR/bqs/201601/mrbqs160101/mrbqs160101t0914c2172_209.fits.gz']

# %%
f = pyfits.open(flist[0])

# %%
f[0].data # the data array is in a list
# Out:
# array([[-1.65193033, -1.65189779, -1.65187001, ..., -1.65205407,
#         -1.65200841, -1.65196705],
#        [-1.51341057, -1.77900732, -1.67968726, ..., -1.09472871,
#         -1.0204407 , -1.22162223],
#        [-0.51791394, -0.41064799, -0.807042  , ..., -1.46112049,
#         -1.04593039, -0.67380774],
#        ...,
#        [-1.17824996, -1.9136138 , -2.45423222, ..., -0.91037953,
#         -0.59628302, -0.6788348 ],
#        [-2.09985709, -2.04305792, -1.75021529, ..., -0.76615334,
#         -1.29350603, -1.74600422],
#        [-1.55610096, -1.55629277, -1.55649221, ..., -1.55557072,
#         -1.55574012, -1.55591691]], dtype=float32)

# %%
imshow(f[0].data)
colorbar()
# Out:
# <matplotlib.colorbar.Colorbar instance at 0xabff894c>

# %%
# Loop over images in flist and create a 3D array with time, y, x indices
images = [] # make a new empty list, same as images = list()
for fname in flist: # loop over each item in flist, with variable fname
    fitsfile = pyfits.open(fname)
    images.append(fitsfile[0].data)
images = array(images)

# %%
# example of more pythonic way to do the same 
images = array([pyfits.open(fname)[0].data for fname in flist])

# %%
images.shape
# Out:
# (103, 180, 360)

# %%
plot(images[:, 95, 220])
